# %%
import os
import pandas as pd
import numpy as np

# %%
files=os.listdir('D:\\ArchivosHDD\\GitHub\\cursoIA2026\\Semana_03\\Ejercicio\\datos\\reglamentonuevo')

# %%
files
# Out:
# ['rendimiento_año_2024_ciclo_2_anon.xlsx',
#  'rendimiento_año_2025_ciclo_1_anon.xlsx',
#  'rendimiento_año_2025_ciclo_2_anon.xlsx']

# %%
DatosConcatenados=pd.DataFrame(columns=['ALUMNO_ID","Cod.Asign","Asignatura","Cod.Car.Sec",Cod.Curso	Convocatoria	Anho	Semestre	Doc.Firma	Aprobado	Anho.Firma	Primer.Par	Segundo.Par	Tercer.Par	TPLab.	Lab.	Proy.	Pond.PP	Pond.SP	Pond.TPLab	Pond.Lab	Pond.Proy	Asis	Requisito	Firma	Primer.Rec	Segundo.Rec	Nota.Final'])
i=0
for filename in files[2:]:
    i=i+1
    print(i)
    print(filename)
    lectura= pd.read_excel(PATH+"\\"+filename, sheet_name="REND",skiprows=0)
    print(filename[27])
    print(filename[16:20])
    lectura['ciclo']=int(filename[27])
    lectura['danho']=int(filename[16:20])
    print(len(lectura))
    DatosConcatenados= pd.concat([DatosConcatenados, lectura], axis=0)
# Out:
# 1
# rendimiento_año_2012_ciclo_1_2021.06.23-09.13.07.xlsx
# C:\Users\yoda\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 1
# 2012
# 7440
# 2
# rendimiento_año_2012_ciclo_2_2021.06.23-09.13.39.xlsx
# 2
# 2012
# 8558
# 3
# rendimiento_año_2013_ciclo_1_2021.06.23-09.13.57.xlsx
# 1
# 2013
# 6012
# 4
# rendimiento_año_2013_ciclo_2_2021.06.23-09.14.19.xlsx
# 2
# 2013
# 10305
# 5
# rendimiento_año_2014_ciclo_1_2021.06.23-09.14.45.xlsx
# 1
# 2014
# 8759
# 6
# rendimiento_año_2014_ciclo_2_2021.06.23-09.15.18.xlsx
# 2
# 2014
# 11485
# 7
# rendimiento_año_2015_ciclo_1_2021.06.23-09.15.41.xlsx
# 1
# 2015
# 9684
# 8
# rendimiento_año_2015_ciclo_2_2021.06.23-09.16.07.xlsx
# 2
# 2015
# 12335
# 9
# rendimiento_año_2016_ciclo_1_2021.06.23-09.16.32.xlsx
# 1
# 2016
# 11086
# 10
# rendimiento_año_2016_ciclo_2_2021.06.23-09.16.58.xlsx
# 2
# ...

# %%
DatosConcatenados.to_csv("datosConcatenados.csv")
# Out:
# <ipython-input-88-df73a371feb2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DatosConcatenado['id_anony'] = labels

# %%
len(uniques)
# Out:
# 4845

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cedula'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-8d113b0c336d> in <module>
# ...

# %%
pd.to_numeric(DatosConcatenados.Cedula, errors='coerce')

# %%
DatosConcatenados[pd.to_numeric(DatosConcatenados.Cedula, errors='coerce').notnull()].to_csv(PATH+"\\datosConcatenadosProblemas.csv")

# %%
DatosConcatenado[(DatosConcatenado['id_anony'])=='es_2526'].to_csv("test.csv")
